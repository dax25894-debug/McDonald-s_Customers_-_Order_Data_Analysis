# %%
import pandas as pd
import matplotlib.pyplot as plt
import ast

# %%
df = pd.read_csv(r'D:\Data Analysis Project\New_MCD\Original - Copy\menu_items.csv')

# %%
df.head(10)
# Out:
#    item_id     item_name  price
# 0      101       Big Mac   18.9
# 1      102     McChicken   16.5
# 2      103  Cheeseburger   10.9
# 3      104         Fries    8.5
# 4      105   Large Fries   10.5
# 5      106          Coke    7.0
# 6      107      McFlurry   12.0
# 7      108        Coffee    6.5

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   item_id    8 non-null      int64
#  1   item_name  8 non-null      str
#  2   price      8 non-null      float64
# dtypes: float64(1), int64(1), str(1)
# memory usage: 324.0 bytes
